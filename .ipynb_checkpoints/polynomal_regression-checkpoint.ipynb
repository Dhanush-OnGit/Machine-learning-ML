# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:/ML csv/Icecream.csv")

# %%
print(data.columns)
# Out:
# Index(['rownames', 'cons', 'income', 'price', 'temperature'], dtype='object')

# %%
x = data['temperature'].values.reshape(-1,1)

# %%
y = data['income'].values

# %%
poly = PolynomialFeatures(degree = 2)

# %%
x_poly = poly.fit_transform(x)

# %%
model = LinearRegression()

# %%
model.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_poly)

# %%
mse = mean_squared_error(y,y_pred)

# %%
r2 = r2_score(y,y_pred)

# %%
plt.figure(figsize= (10,5))
plt.scatter(x,y,label = "data",color = "red")
x_sort = np.sort(x,axis = 0)
x_sort_poly = poly.transform(x_sort)
y_sort = model.predict(x_sort_poly)
plt.plot(x_sort,y_sort,label = "polynomial",color = "green")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
print(f"mean squared error : {mse}")
print(f"r2 score : {r2}")
# Out:
# mean squared error : 33.2523315153883
# r2 score : 0.11813123633163991
