# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:/ML csv/training_data.csv")

# %%
print(data.columns)
# Out:
# Index(['x', 'y'], dtype='object')

# %%
x = data['x'].values.reshape(-1,1)

# %%
y = data['y'].values

# %%
data_cleaned = data.dropna(subset = ['y'])

# %%
x = data_cleaned['x'].values.reshape(-1,1)

# %%
y = data_cleaned['y'].values

# %%
y_filled = np.nan_to_num(y,nan = np.nanmean(y))

# %%
y = y_filled

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
mse = mean_squared_error(y,y_pred)

# %%
r2 = r2_score(y,y_pred)

# %%
plt.scatter(x,y,label="Data points")
plt.plot(x,y_pred,color="red",label = "Regression")
plt.xlabel('x')
plt.ylabel('y')
plt.title("Single linear regression")
plt.legend()
plt.show()

# %%
print(f"mean squared error : {mse}")
# Out:
# mean squared error : 7.867752733487689

# %%
print(f"r2 score : {r2}")
# Out:
# r2 score : 0.9907015319025518
